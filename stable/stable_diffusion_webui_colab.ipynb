# %% [markdown]
# <a href="https://colab.research.google.com/github/codershiv2021/Boiler_plate/blob/smooth-menu/stable/stable_diffusion_webui_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui /content/stable-diffusion-webui

# %%
# %cd /content/stable-diffusion-webui

# %%
# !pip install -r requirements_versions.txt --extra-index-url https://download.pytorch.org/whl/cu118

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir -p /content/stable-diffusion-webui/models/Stable-diffusion

# %%
# !cp "/content/drive/MyDrive/cyberrealisticXL_v57.safetensors" /content/stable-diffusion-webui/models/Stable-diffusion/

# %%
# !COMMANDLINE_ARGS="--share --no-half --precision full" python launch.py
